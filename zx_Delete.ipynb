# %%
import os
import glob

def delete_doc_and_text_files(folder_paths, file_names=None):
    for folder in folder_paths:
        if file_names:  # Check if specific file names are provided
            for file_name in file_names:
                # Construct the specific file paths for each file_name
                doc_file = os.path.join(folder, f'{file_name}.doc')
                docx_file = os.path.join(folder, f'{file_name}.docx')
                txt_file = os.path.join(folder, f'{file_name}.txt')

                # Try to delete the specific files
                for file in [doc_file, docx_file, txt_file]:
                    if os.path.exists(file):
                        try:
                            os.remove(file)
                            print(f'Deleted: {file}')
                        except Exception as e:
                            print(f'Error deleting {file}: {e}')
                    else:
                        print(f'*')
        else:
            # Construct the search patterns for .doc, .docx, and .txt files
            doc_pattern = os.path.join(folder, '*.doc')
            docx_pattern = os.path.join(folder, '*.docx')
            txt_pattern = os.path.join(folder, '*.txt')

            # Delete all .doc files
            for doc_file in glob.glob(doc_pattern):
                try:
                    os.remove(doc_file)
                    print(f'Deleted: {doc_file}')
                except Exception as e:
                    print(f'Error deleting {doc_file}: {e}')

            # Delete all .docx files
            for docx_file in glob.glob(docx_pattern):
                try:
                    os.remove(docx_file)
                    print(f'Deleted: {docx_file}')
                except Exception as e:
                    print(f'Error deleting {docx_file}: {e}')

            # Delete all .txt files
            for txt_file in glob.glob(txt_pattern):
                try:
                    os.remove(txt_file)
                    print(f'Deleted: {txt_file}')
                except Exception as e:
                    print(f'Error deleting {txt_file}: {e}')

# Example usage
folder_paths = [
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\1_DocFile',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\2_With_Bullets',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\3_Bullets Sequence',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\3_Character Sequence',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\4_Clean Bullets',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\4_Clean Sequence',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\5_Formatted Bullets',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\5_Formatted Sequence',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\7_Question Range',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\8_Options Range',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\9_Order Sequence',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\10_Arrangement Done',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\12_Fast doc',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\12_FileName Update',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\12_Final doc',
]

# To delete specific files by name (without extension)
# delete_doc_and_text_files(folder_paths, file_names=["DPP39", "DPP40", "DPP44", "DPP48", "DPP50", "DPP51", "DPP52", "DPP53", "DPP54", "DPP56", "DPP59"])

# To delete all files if no specific file names are given
delete_doc_and_text_files(folder_paths)
# Out:
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-1.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-10.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-11.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-12.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-13.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-14.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-15.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-16.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-17.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-18.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-19.docx
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\12_FileName Update\CH-2.docx
# ...

# %%
import os
import glob

def delete_doc_and_text_files(folder_paths, file_names=None):
    for folder in folder_paths:
        if file_names:  # Check if specific file names are provided
            for file_name in file_names:
                # Construct the specific file paths for each file_name
                doc_file = os.path.join(folder, f'{file_name}.doc')
                docx_file = os.path.join(folder, f'{file_name}.docx')
                txt_file = os.path.join(folder, f'{file_name}.txt')

                # Try to delete the specific files
                for file in [doc_file, docx_file, txt_file]:
                    if os.path.exists(file):
                        try:
                            os.remove(file)
                            print(f'Deleted: {file_name}')
                        except Exception as e:
                            print(f'Error deleting {file}: {e}')
                    else:
                        print(f'*')
        else:
            # Construct the search patterns for .doc, .docx, and .txt files
            doc_pattern = os.path.join(folder, '*.doc')
            docx_pattern = os.path.join(folder, '*.docx')
            txt_pattern = os.path.join(folder, '*.txt')

            # Delete all .doc files
            for doc_file in glob.glob(doc_pattern):
                try:
                    os.remove(doc_file)
                    print(f'Deleted: {doc_file}')
                except Exception as e:
                    print(f'Error deleting {doc_file}: {e}')

            # Delete all .docx files
            for docx_file in glob.glob(docx_pattern):
                try:
                    os.remove(docx_file)
                    print(f'Deleted: {docx_file}')
                except Exception as e:
                    print(f'Error deleting {docx_file}: {e}')

            # Delete all .txt files
            for txt_file in glob.glob(txt_pattern):
                try:
                    os.remove(txt_file)
                    print(f'Deleted: {txt_file}')
                except Exception as e:
                    print(f'Error deleting {txt_file}: {e}')

# Example usage
folder_paths = [
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\13_Answer Key',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\14_Reorder Answer Key',
    r'C:\Users\uk880\OneDrive\Desktop\RapidPaste\Xoom File',
]

# To delete all files if no specific file names are given
delete_doc_and_text_files(folder_paths)
# Out:
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-1.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-10.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-11.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-12.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-13.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-14.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-15.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-16.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-17.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-18.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-19.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-2.txt
# Deleted: C:\Users\uk880\OneDrive\Desktop\Paisa\13_Answer Key\CH-20.txt
# ...
